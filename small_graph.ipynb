# %%
import pandas as pd

# Load the file
line_ref = pd.read_csv('referentiel-des-lignes.csv', sep=';')

# Create a dictionary mapping line names to their hex colors
line_colors = dict(zip(line_ref['ShortName_Line'], line_ref['ColourWeb_hexa']))

# Example lookup
line_colors['4']
# Out:
# '82dc73'
